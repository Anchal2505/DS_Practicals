# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
Math_score = [random.randint(60, 80) for _ in range(400)]
missing_pct = 0.2  # 20% missing values

# Calculate the number of missing values
n_missing = int(len(Math_score) * missing_pct)

# Generate a list of indices to replace with missing values
missing_indices = random.sample(range(len(Math_score)), n_missing)

# Replace the values at the missing indices with None
for i in missing_indices:
    Math_score[i] = None

# %%
Math_score
# Out:
# [78,
#  68,
#  79,
#  66,
#  None,
#  76,
#  78,
#  66,
#  79,
#  79,
#  80,
#  None,
#  78,
#  None,
#  68,
#  None,
#  63,
#  68,
#  69,
#  68,
#  71,
#  72,
#  65,
#  79,
#  74,
#  76,
#  74,
#  63,
#  79,
#  76,
#  77,
#  63,
#  80,
#  67,
#  72,
#  72,
#  66,
#  72,
#  None,
#  78,
#  67,
#  77,
#  76,
#  62,
#  66,
#  64,
#  80,
#  None,
#  72,
#  77,
#  80,
#  76,
#  76,
#  76,
#  69,
#  63,
#  79,
#  74,
#  None,
#  77,
#  79,
#  63,
#  70,
#  68,
#  None,
#  61,
#  None,
#  77,
#  None,
#  76,
#  63,
#  None,
#  78,
#  72,
#  66,
#  None,
#  79,
#  None,
#  76,
#  73,
#  None,
#  72,
#  60,
#  68,
#  62,
#  77,
#  None,
#  71,
#  None,
#  69,
#  79,
#  71,
#  76,
#  69,
#  75,
#  72,
#  74,
#  71,
#  80,
#  76,
#  71,
#  62,
#  None,
#  78,
#  61,
#  77,
#  72,
#  None,
#  None,
#  78,
#  74,
#  None,
#  79,
#  75,
#  67,
#  None,
#  None,
#  66,
#  61,
#  None,
#  74,
#  64,
#  67,
#  61,
#  67,
#  None,
#  None,
#  66,
#  None,
#  64,
#  67,
#  66,
#  None,
#  None,
#  73,
#  None,
#  74,
#  78,
#  77,
#  70,
#  None,
#  None,
#  78,
#  77,
#  63,
#  69,
#  80,
#  None,
#  72,
#  72,
#  62,
#  75,
#  73,
#  71,
#  66,
#  68,
#  66,
#  None,
#  60,
#  65,
#  77,
#  None,
#  None,
#  60,
#  64,
#  None,
#  None,
#  68,
#  66,
#  70,
#  74,
#  71,
#  72,
#  63,
#  79,
#  72,
#  None,
#  73,
#  66,
#  65,
#  73,
#  None,
#  None,
#  72,
#  None,
#  64,
#  61,
#  71,
#  67,
#  60,
#  62,
#  79,
#  None,
#  64,
#  65,
#  None,
#  None,
#  61,
#  69,
#  61,
#  76,
#  65,
#  60,
#  68,
#  60,
#  65,
#  65,
#  None,
#  67,
#  79,
#  61,
#  66,
#  None,
#  70,
#  None,
#  72,
#  69,
#  75,
#  63,
#  63,
#  77,
#  61,
#  None,
#  66,
#  77,
#  66,
#  70,
#  None,
#  60,
#  77,
#  None,
#  63,
#  None,
#  74,
#  65,
#  71,
#  74,
#  None,
#  68,
#  70,
#  61,
#  60,
#  None,
#  63,
#  71,
#  69,
#  73,
#  66,
#  None,
#  76,
#  73,
#  62,
#  74,
#  None,
#  78,
#  80,
#  60,
#  72,
#  68,
#  None,
#  None,
#  72,
#  78,
#  75,
#  79,
#  62,
#  None,
#  66,
#  62,
#  None,
#  None,
#  63,
#  76,
#  72,
#  78,
#  None,
#  75,
#  63,
#  79,
#  63,
#  64,
#  67,
#  71,
#  None,
#  None,
#  75,
#  75,
#  None,
#  78,
#  65,
#  62,
#  73,
#  64,
#  78,
#  None,
#  70,
#  67,
#  71,
#  62,
#  71,
#  72,
#  67,
#  74,
#  79,
#  66,
#  64,
#  76,
#  77,
#  66,
#  None,
#  61,
#  72,
#  65,
#  73,
#  62,
#  79,
#  77,
#  None,
#  73,
#  73,
#  65,
#  72,
#  None,
#  None,
#  79,
#  None,
#  63,
#  66,
#  72,
#  65,
#  None,
#  80,
#  72,
#  66,
#  67,
#  73,
#  None,
#  74,
#  74,
#  80,
#  80,
#  76,
#  60,
#  63,
#  None,
#  61,
#  64,
#  73,
#  74,
#  67,
#  None,
#  77,
#  73,
#  76,
#  79,
#  61,
#  None,
#  79,
#  71,
#  80,
#  62,
#  61,
#  60,
#  65,
#  64,
#  71,
#  None,
#  64,
#  68,
#  68,
#  76,
#  78,
#  66,
#  None,
#  None,
#  79,
#  64,
#  None,
#  78,
#  77,
#  70,
#  62,
#  65,
#  60,
#  71,
#  79,
#  66,
#  80,
#  61,
#  70,
#  70,
#  73,
#  68,
#  65,
#  78,
#  67,
#  69,
#  None,
#  71,
#  66]

# %%
Reading_score = [random.randint(75, 95) for _ in range(400)]
missing_pct = 0.1  # 10% missing values

# Calculate the number of missing values
n_missing = int(len(Reading_score) * missing_pct)

# Generate a list of indices to replace with missing values
missing_indices = random.sample(range(len(Reading_score)), n_missing)

# Replace the values at the missing indices with None
for i in missing_indices:
    Reading_score[i] = None

# %%
Reading_score
# Out:
# [80,
#  84,
#  87,
#  None,
#  85,
#  77,
#  None,
#  None,
#  91,
#  75,
#  76,
#  88,
#  77,
#  86,
#  83,
#  95,
#  89,
#  85,
#  77,
#  75,
#  75,
#  85,
#  83,
#  94,
#  94,
#  88,
#  76,
#  None,
#  76,
#  81,
#  None,
#  90,
#  None,
#  85,
#  94,
#  86,
#  76,
#  90,
#  77,
#  90,
#  82,
#  90,
#  95,
#  81,
#  95,
#  87,
#  82,
#  None,
#  85,
#  87,
#  75,
#  84,
#  92,
#  75,
#  84,
#  93,
#  80,
#  90,
#  76,
#  85,
#  75,
#  None,
#  91,
#  84,
#  82,
#  80,
#  75,
#  90,
#  92,
#  78,
#  76,
#  None,
#  90,
#  93,
#  83,
#  75,
#  84,
#  79,
#  75,
#  94,
#  81,
#  86,
#  81,
#  79,
#  None,
#  79,
#  95,
#  75,
#  87,
#  81,
#  95,
#  81,
#  76,
#  82,
#  77,
#  92,
#  80,
#  84,
#  89,
#  86,
#  89,
#  81,
#  87,
#  86,
#  95,
#  82,
#  79,
#  84,
#  None,
#  87,
#  92,
#  84,
#  82,
#  81,
#  82,
#  78,
#  None,
#  None,
#  81,
#  90,
#  90,
#  95,
#  79,
#  81,
#  None,
#  95,
#  86,
#  79,
#  None,
#  75,
#  89,
#  77,
#  75,
#  87,
#  92,
#  None,
#  None,
#  77,
#  94,
#  94,
#  77,
#  79,
#  87,
#  80,
#  93,
#  86,
#  89,
#  84,
#  89,
#  80,
#  92,
#  82,
#  90,
#  93,
#  82,
#  91,
#  88,
#  None,
#  None,
#  92,
#  83,
#  77,
#  None,
#  86,
#  86,
#  89,
#  77,
#  92,
#  75,
#  75,
#  83,
#  95,
#  83,
#  95,
#  92,
#  75,
#  81,
#  78,
#  84,
#  76,
#  92,
#  81,
#  92,
#  82,
#  94,
#  94,
#  81,
#  94,
#  None,
#  80,
#  79,
#  89,
#  79,
#  85,
#  86,
#  81,
#  83,
#  80,
#  78,
#  None,
#  76,
#  82,
#  80,
#  95,
#  76,
#  89,
#  78,
#  86,
#  82,
#  84,
#  78,
#  94,
#  80,
#  None,
#  78,
#  95,
#  79,
#  None,
#  87,
#  95,
#  76,
#  None,
#  93,
#  81,
#  94,
#  84,
#  94,
#  90,
#  88,
#  76,
#  90,
#  90,
#  93,
#  77,
#  87,
#  None,
#  92,
#  None,
#  76,
#  90,
#  None,
#  86,
#  94,
#  90,
#  89,
#  84,
#  94,
#  85,
#  75,
#  94,
#  83,
#  81,
#  82,
#  75,
#  88,
#  82,
#  79,
#  88,
#  85,
#  80,
#  88,
#  91,
#  None,
#  84,
#  86,
#  93,
#  78,
#  77,
#  None,
#  75,
#  81,
#  90,
#  77,
#  87,
#  84,
#  79,
#  89,
#  92,
#  None,
#  None,
#  89,
#  83,
#  81,
#  91,
#  80,
#  87,
#  None,
#  76,
#  None,
#  84,
#  87,
#  88,
#  82,
#  81,
#  75,
#  95,
#  83,
#  87,
#  77,
#  93,
#  89,
#  78,
#  91,
#  82,
#  77,
#  95,
#  84,
#  83,
#  82,
#  89,
#  85,
#  80,
#  88,
#  84,
#  75,
#  75,
#  86,
#  92,
#  78,
#  89,
#  83,
#  93,
#  None,
#  85,
#  94,
#  85,
#  79,
#  76,
#  90,
#  88,
#  95,
#  None,
#  75,
#  84,
#  85,
#  78,
#  83,
#  87,
#  75,
#  80,
#  88,
#  90,
#  86,
#  91,
#  93,
#  None,
#  93,
#  94,
#  None,
#  85,
#  94,
#  77,
#  91,
#  85,
#  90,
#  95,
#  82,
#  None,
#  81,
#  85,
#  75,
#  77,
#  82,
#  87,
#  87,
#  81,
#  93,
#  80,
#  94,
#  82,
#  89,
#  79,
#  None,
#  76,
#  84,
#  83,
#  90,
#  77,
#  94,
#  87,
#  78,
#  91,
#  89,
#  76,
#  82,
#  86,
#  75,
#  92,
#  79,
#  87,
#  91,
#  95,
#  95,
#  77,
#  95,
#  93,
#  84,
#  80,
#  90,
#  81]

# %%
Writing_score = [random.randint(60, 80) for _ in range(400)]

# %%
Writing_score
# Out:
# [76,
#  78,
#  61,
#  70,
#  63,
#  61,
#  68,
#  66,
#  60,
#  62,
#  80,
#  64,
#  76,
#  68,
#  79,
#  60,
#  65,
#  79,
#  79,
#  71,
#  79,
#  69,
#  64,
#  80,
#  61,
#  78,
#  80,
#  72,
#  72,
#  76,
#  74,
#  80,
#  77,
#  70,
#  77,
#  62,
#  63,
#  66,
#  76,
#  76,
#  66,
#  72,
#  63,
#  66,
#  69,
#  71,
#  69,
#  60,
#  72,
#  78,
#  78,
#  68,
#  73,
#  76,
#  66,
#  63,
#  80,
#  63,
#  77,
#  70,
#  63,
#  67,
#  60,
#  64,
#  68,
#  76,
#  61,
#  76,
#  61,
#  73,
#  70,
#  79,
#  63,
#  61,
#  75,
#  62,
#  64,
#  72,
#  72,
#  80,
#  67,
#  77,
#  61,
#  70,
#  71,
#  65,
#  71,
#  73,
#  66,
#  78,
#  72,
#  67,
#  76,
#  78,
#  63,
#  75,
#  79,
#  71,
#  61,
#  64,
#  68,
#  65,
#  61,
#  62,
#  65,
#  68,
#  74,
#  64,
#  71,
#  67,
#  71,
#  69,
#  68,
#  80,
#  70,
#  63,
#  76,
#  78,
#  66,
#  67,
#  60,
#  74,
#  75,
#  71,
#  66,
#  77,
#  60,
#  67,
#  71,
#  72,
#  63,
#  68,
#  80,
#  72,
#  72,
#  69,
#  71,
#  69,
#  66,
#  69,
#  73,
#  76,
#  70,
#  64,
#  63,
#  64,
#  74,
#  72,
#  74,
#  60,
#  79,
#  75,
#  69,
#  60,
#  63,
#  60,
#  75,
#  63,
#  65,
#  63,
#  80,
#  80,
#  77,
#  79,
#  78,
#  72,
#  60,
#  67,
#  66,
#  63,
#  77,
#  73,
#  66,
#  78,
#  65,
#  76,
#  73,
#  78,
#  63,
#  79,
#  70,
#  64,
#  64,
#  78,
#  60,
#  77,
#  60,
#  74,
#  69,
#  71,
#  72,
#  74,
#  72,
#  62,
#  66,
#  60,
#  62,
#  64,
#  80,
#  60,
#  74,
#  66,
#  72,
#  61,
#  74,
#  77,
#  71,
#  76,
#  64,
#  65,
#  66,
#  69,
#  65,
#  77,
#  73,
#  74,
#  70,
#  62,
#  76,
#  78,
#  62,
#  71,
#  74,
#  62,
#  78,
#  75,
#  66,
#  78,
#  65,
#  65,
#  80,
#  76,
#  72,
#  74,
#  65,
#  61,
#  65,
#  77,
#  71,
#  78,
#  78,
#  76,
#  62,
#  76,
#  77,
#  80,
#  65,
#  70,
#  70,
#  80,
#  77,
#  66,
#  71,
#  69,
#  78,
#  73,
#  74,
#  68,
#  66,
#  64,
#  68,
#  72,
#  67,
#  79,
#  72,
#  75,
#  73,
#  73,
#  68,
#  72,
#  77,
#  60,
#  78,
#  71,
#  75,
#  63,
#  77,
#  76,
#  75,
#  62,
#  69,
#  61,
#  69,
#  77,
#  75,
#  75,
#  61,
#  70,
#  63,
#  72,
#  64,
#  65,
#  69,
#  77,
#  71,
#  71,
#  64,
#  69,
#  75,
#  68,
#  63,
#  79,
#  60,
#  75,
#  76,
#  60,
#  79,
#  61,
#  75,
#  80,
#  70,
#  60,
#  70,
#  65,
#  71,
#  65,
#  65,
#  60,
#  63,
#  77,
#  67,
#  73,
#  76,
#  75,
#  79,
#  70,
#  73,
#  78,
#  60,
#  79,
#  64,
#  72,
#  79,
#  70,
#  74,
#  75,
#  78,
#  78,
#  79,
#  63,
#  76,
#  80,
#  64,
#  66,
#  69,
#  68,
#  74,
#  77,
#  69,
#  79,
#  74,
#  79,
#  78,
#  64,
#  76,
#  72,
#  68,
#  78,
#  69,
#  64,
#  71,
#  67,
#  69,
#  62,
#  74,
#  63,
#  61,
#  78,
#  78,
#  65,
#  71,
#  80,
#  67,
#  66,
#  76,
#  73,
#  77,
#  79,
#  60,
#  67,
#  76,
#  73,
#  63,
#  68,
#  69,
#  61,
#  78,
#  76,
#  75,
#  74,
#  62,
#  71,
#  62,
#  73,
#  67,
#  67,
#  63,
#  71,
#  64,
#  77]

# %%
Placement_score = [random.randint(75, 100) for _ in range(400)]

# %%
Placement_score
# Out:
# [97,
#  99,
#  93,
#  100,
#  98,
#  77,
#  94,
#  81,
#  90,
#  89,
#  95,
#  99,
#  84,
#  96,
#  75,
#  75,
#  90,
#  83,
#  89,
#  90,
#  79,
#  82,
#  86,
#  82,
#  99,
#  93,
#  85,
#  89,
#  100,
#  79,
#  96,
#  88,
#  82,
#  83,
#  81,
#  77,
#  86,
#  87,
#  87,
#  76,
#  76,
#  75,
#  87,
#  76,
#  84,
#  85,
#  95,
#  89,
#  99,
#  94,
#  94,
#  97,
#  88,
#  82,
#  93,
#  94,
#  91,
#  80,
#  78,
#  85,
#  96,
#  95,
#  90,
#  81,
#  81,
#  95,
#  76,
#  75,
#  85,
#  76,
#  96,
#  79,
#  76,
#  86,
#  97,
#  86,
#  76,
#  75,
#  82,
#  75,
#  87,
#  100,
#  80,
#  97,
#  79,
#  85,
#  79,
#  96,
#  86,
#  87,
#  85,
#  88,
#  96,
#  82,
#  80,
#  84,
#  95,
#  83,
#  81,
#  85,
#  75,
#  85,
#  93,
#  95,
#  92,
#  81,
#  83,
#  88,
#  83,
#  94,
#  77,
#  87,
#  86,
#  82,
#  90,
#  84,
#  89,
#  86,
#  82,
#  77,
#  98,
#  98,
#  99,
#  92,
#  97,
#  83,
#  87,
#  82,
#  75,
#  89,
#  91,
#  76,
#  94,
#  87,
#  85,
#  82,
#  85,
#  86,
#  99,
#  86,
#  86,
#  89,
#  94,
#  81,
#  75,
#  89,
#  90,
#  98,
#  95,
#  94,
#  83,
#  87,
#  80,
#  100,
#  81,
#  77,
#  75,
#  82,
#  85,
#  75,
#  79,
#  90,
#  77,
#  75,
#  82,
#  91,
#  77,
#  100,
#  77,
#  85,
#  90,
#  96,
#  82,
#  96,
#  82,
#  77,
#  98,
#  87,
#  92,
#  100,
#  94,
#  86,
#  89,
#  75,
#  90,
#  96,
#  87,
#  86,
#  82,
#  88,
#  99,
#  87,
#  85,
#  100,
#  79,
#  80,
#  89,
#  79,
#  78,
#  96,
#  92,
#  88,
#  97,
#  82,
#  99,
#  95,
#  99,
#  83,
#  85,
#  79,
#  87,
#  75,
#  81,
#  91,
#  75,
#  86,
#  83,
#  95,
#  75,
#  100,
#  93,
#  100,
#  75,
#  90,
#  100,
#  96,
#  86,
#  89,
#  93,
#  82,
#  95,
#  99,
#  82,
#  88,
#  93,
#  78,
#  86,
#  93,
#  81,
#  78,
#  86,
#  94,
#  84,
#  91,
#  98,
#  84,
#  98,
#  95,
#  91,
#  76,
#  84,
#  86,
#  96,
#  79,
#  93,
#  76,
#  91,
#  87,
#  78,
#  90,
#  84,
#  89,
#  85,
#  91,
#  82,
#  93,
#  94,
#  99,
#  93,
#  91,
#  77,
#  93,
#  100,
#  89,
#  91,
#  87,
#  96,
#  91,
#  88,
#  76,
#  91,
#  92,
#  81,
#  87,
#  79,
#  76,
#  100,
#  97,
#  88,
#  77,
#  90,
#  94,
#  100,
#  85,
#  92,
#  81,
#  96,
#  90,
#  90,
#  86,
#  92,
#  91,
#  95,
#  90,
#  97,
#  100,
#  75,
#  93,
#  76,
#  96,
#  97,
#  84,
#  83,
#  81,
#  89,
#  96,
#  100,
#  76,
#  76,
#  100,
#  81,
#  77,
#  78,
#  90,
#  82,
#  87,
#  93,
#  78,
#  81,
#  99,
#  99,
#  97,
#  87,
#  97,
#  89,
#  84,
#  77,
#  86,
#  78,
#  80,
#  95,
#  78,
#  95,
#  84,
#  84,
#  77,
#  81,
#  81,
#  94,
#  85,
#  77,
#  87,
#  76,
#  82,
#  81,
#  93,
#  76,
#  83,
#  83,
#  100,
#  95,
#  83,
#  90,
#  76,
#  90,
#  79,
#  98,
#  96,
#  94,
#  78,
#  79,
#  99,
#  90,
#  88,
#  83,
#  88,
#  82,
#  80,
#  89,
#  77,
#  88,
#  98,
#  84,
#  88,
#  89,
#  78,
#  89,
#  80,
#  88,
#  81,
#  86,
#  90,
#  82,
#  79,
#  83,
#  92,
#  87,
#  91,
#  95,
#  76]

# %%
Club_list = ['2018', '2019','2020', '2021']
Club_Join_Date= [random.choice(Club_list) for _ in range(400)]

# %%
Club_Join_Date
# Out:
# ['2021',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2021',
#  '2018',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2019',
#  '2020',
#  '2021',
#  '2019',
#  '2018',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2018',
#  '2021',
#  '2019',
#  '2020',
#  '2018',
#  '2020',
#  '2019',
#  '2018',
#  '2018',
#  '2020',
#  '2018',
#  '2019',
#  '2018',
#  '2019',
#  '2020',
#  '2019',
#  '2021',
#  '2018',
#  '2018',
#  '2021',
#  '2020',
#  '2020',
#  '2018',
#  '2020',
#  '2018',
#  '2021',
#  '2019',
#  '2020',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2021',
#  '2021',
#  '2018',
#  '2018',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2019',
#  '2018',
#  '2021',
#  '2021',
#  '2018',
#  '2018',
#  '2021',
#  '2021',
#  '2019',
#  '2018',
#  '2020',
#  '2019',
#  '2021',
#  '2019',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2018',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2019',
#  '2021',
#  '2019',
#  '2021',
#  '2021',
#  '2020',
#  '2021',
#  '2019',
#  '2021',
#  '2019',
#  '2018',
#  '2021',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2020',
#  '2018',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2018',
#  '2019',
#  '2020',
#  '2018',
#  '2021',
#  '2020',
#  '2019',
#  '2019',
#  '2020',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2021',
#  '2020',
#  '2021',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2019',
#  '2021',
#  '2021',
#  '2018',
#  '2020',
#  '2020',
#  '2021',
#  '2018',
#  '2021',
#  '2018',
#  '2021',
#  '2019',
#  '2020',
#  '2021',
#  '2018',
#  '2021',
#  '2021',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2018',
#  '2018',
#  '2021',
#  '2020',
#  '2020',
#  '2018',
#  '2019',
#  '2021',
#  '2018',
#  '2021',
#  '2018',
#  '2018',
#  '2018',
#  '2020',
#  '2018',
#  '2020',
#  '2021',
#  '2018',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2021',
#  '2021',
#  '2018',
#  '2019',
#  '2018',
#  '2019',
#  '2018',
#  '2018',
#  '2019',
#  '2021',
#  '2019',
#  '2021',
#  '2021',
#  '2020',
#  '2019',
#  '2021',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2021',
#  '2018',
#  '2018',
#  '2018',
#  '2020',
#  '2021',
#  '2018',
#  '2021',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2019',
#  '2019',
#  '2021',
#  '2021',
#  '2018',
#  '2019',
#  '2018',
#  '2019',
#  '2019',
#  '2021',
#  '2019',
#  '2019',
#  '2020',
#  '2018',
#  '2018',
#  '2019',
#  '2021',
#  '2018',
#  '2019',
#  '2019',
#  '2020',
#  '2021',
#  '2020',
#  '2018',
#  '2019',
#  '2021',
#  '2018',
#  '2018',
#  '2018',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2018',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2020',
#  '2021',
#  '2019',
#  '2020',
#  '2019',
#  '2018',
#  '2020',
#  '2019',
#  '2020',
#  '2018',
#  '2018',
#  '2019',
#  '2018',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2018',
#  '2020',
#  '2018',
#  '2021',
#  '2019',
#  '2021',
#  '2021',
#  '2021',
#  '2018',
#  '2021',
#  '2020',
#  '2021',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2021',
#  '2019',
#  '2018',
#  '2021',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2021',
#  '2018',
#  '2021',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2020',
#  '2018',
#  '2019',
#  '2019',
#  '2018',
#  '2021',
#  '2021',
#  '2019',
#  '2019',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2019',
#  '2020',
#  '2021',
#  '2019',
#  '2020',
#  '2019',
#  '2019',
#  '2018',
#  '2020',
#  '2021',
#  '2019',
#  '2019',
#  '2018',
#  '2020',
#  '2019',
#  '2020',
#  '2021',
#  '2019',
#  '2019',
#  '2020',
#  '2018',
#  '2020',
#  '2018',
#  '2020',
#  '2020',
#  '2019',
#  '2021',
#  '2019',
#  '2018',
#  '2018',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2019',
#  '2021',
#  '2019',
#  '2021',
#  '2020',
#  '2020',
#  '2018',
#  '2019',
#  '2018',
#  '2018',
#  '2019',
#  '2018',
#  '2019',
#  '2018',
#  '2020',
#  '2020',
#  '2018',
#  '2020',
#  '2020',
#  '2019',
#  '2021',
#  '2019',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2019',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2018',
#  '2019',
#  '2021',
#  '2020']

# %%
df = {}

df["Math_score"] = Math_score
df['Reading_score'] = Reading_score
df["Writing_score"] = Writing_score
df["Placement_score"] =Placement_score
df["Club_Join_Date"] = Club_Join_Date

# %%
df
# Out:
# {'Math_score': [78,
#   68,
#   79,
#   66,
#   None,
#   76,
#   78,
#   66,
#   79,
#   79,
#   80,
#   None,
#   78,
#   None,
#   68,
#   None,
#   63,
#   68,
#   69,
#   68,
#   71,
#   72,
#   65,
#   79,
#   74,
#   76,
#   74,
#   63,
#   79,
#   76,
#   77,
#   63,
#   80,
#   67,
#   72,
#   72,
#   66,
#   72,
#   None,
#   78,
#   67,
#   77,
#   76,
#   62,
#   66,
#   64,
#   80,
#   None,
#   72,
#   77,
#   80,
#   76,
#   76,
#   76,
#   69,
#   63,
#   79,
#   74,
#   None,
#   77,
#   79,
#   63,
#   70,
#   68,
#   None,
#   61,
#   None,
#   77,
#   None,
#   76,
#   63,
#   None,
#   78,
#   72,
#   66,
#   None,
#   79,
#   None,
#   76,
#   73,
#   None,
#   72,
#   60,
#   68,
#   62,
#   77,
#   None,
#   71,
#   None,
#   69,
#   79,
#   71,
#   76,
#   69,
#   75,
#   72,
#   74,
#   71,
#   80,
#   76,
#   71,
#   62,
#   None,
#   78,
#   61,
#   77,
#   72,
#   None,
#   None,
#   78,
#   74,
#   None,
#   79,
#   75,
#   67,
#   None,
#   None,
#   66,
#   61,
#   None,
#   74,
#   64,
#   67,
#   61,
#   67,
#   None,
#   None,
#   66,
#   None,
#   64,
#   67,
#   66,
#   None,
#   None,
#   73,
#   None,
#   74,
#   78,
#   77,
#   70,
#   None,
#   None,
#   78,
#   77,
#   63,
#   69,
#   80,
#   None,
#   72,
#   72,
#   62,
#   75,
#   73,
#   71,
#   66,
#   68,
#   66,
#   None,
#   60,
#   65,
#   77,
#   None,
#   None,
#   60,
#   64,
#   None,
#   None,
#   68,
#   66,
#   70,
#   74,
#   71,
#   72,
#   63,
#   79,
#   72,
#   None,
#   73,
#   66,
#   65,
#   73,
#   None,
#   None,
#   72,
#   None,
#   64,
#   61,
#   71,
#   67,
#   60,
#   62,
#   79,
#   None,
#   64,
#   65,
#   None,
#   None,
#   61,
#   69,
#   61,
#   76,
#   65,
#   60,
#   68,
#   60,
#   65,
#   65,
#   None,
#   67,
#   79,
#   61,
#   66,
#   None,
#   70,
#   None,
#   72,
#   69,
#   75,
#   63,
#   63,
#   77,
#   61,
#   None,
#   66,
#   77,
#   66,
#   70,
#   None,
#   60,
#   77,
#   None,
#   63,
#   None,
#   74,
#   65,
#   71,
#   74,
#   None,
#   68,
#   70,
#   61,
#   60,
#   None,
#   63,
#   71,
#   69,
#   73,
#   66,
#   None,
#   76,
#   73,
#   62,
#   74,
#   None,
#   78,
#   80,
#   60,
#   72,
#   68,
#   None,
#   None,
#   72,
#   78,
#   75,
#   79,
#   62,
#   None,
#   66,
#   62,
#   None,
#   None,
#   63,
#   76,
#   72,
#   78,
#   None,
#   75,
#   63,
#   79,
#   63,
#   64,
#   67,
#   71,
#   None,
#   None,
#   75,
#   75,
#   None,
#   78,
#   65,
#   62,
#   73,
#   64,
#   78,
#   None,
#   70,
#   67,
#   71,
#   62,
#   71,
#   72,
#   67,
#   74,
#   79,
#   66,
#   64,
#   76,
#   77,
#   66,
#   None,
#   61,
#   72,
#   65,
#   73,
#   62,
#   79,
#   77,
#   None,
#   73,
#   73,
#   65,
#   72,
#   None,
#   None,
#   79,
#   None,
#   63,
#   66,
#   72,
#   65,
#   None,
#   80,
#   72,
#   66,
#   67,
#   73,
#   None,
#   74,
#   74,
#   80,
#   80,
#   76,
#   60,
#   63,
#   None,
#   61,
#   64,
#   73,
#   74,
#   67,
#   None,
#   77,
#   73,
#   76,
#   79,
#   61,
#   None,
#   79,
#   71,
#   80,
#   62,
#   61,
#   60,
#   65,
#   64,
#   71,
#   None,
#   64,
#   68,
#   68,
#   76,
#   78,
#   66,
#   None,
#   None,
#   79,
#   64,
#   None,
#   78,
#   77,
#   70,
#   62,
#   65,
#   60,
#   71,
#   79,
#   66,
#   80,
#   61,
#   70,
#   70,
#   73,
#   68,
#   65,
#   78,
#   67,
#   69,
#   None,
#   71,
#   66],
#  'Reading_score': [80,
#   84,
#   87,
#   None,
#   85,
#   77,
#   None,
#   None,
#   91,
#   75,
#   76,
#   88,
#   77,
#   86,
#   83,
#   95,
#   89,
#   85,
#   77,
#   75,
#   75,
#   85,
#   83,
#   94,
#   94,
#   88,
#   76,
#   None,
#   76,
#   81,
#   None,
#   90,
#   None,
#   85,
#   94,
#   86,
#   76,
#   90,
#   77,
#   90,
#   82,
#   90,
#   95,
#   81,
#   95,
#   87,
#   82,
#   None,
#   85,
#   87,
#   75,
#   84,
#   92,
#   75,
#   84,
#   93,
#   80,
#   90,
#   76,
#   85,
#   75,
#   None,
#   91,
#   84,
#   82,
#   80,
#   75,
#   90,
#   92,
#   78,
#   76,
#   None,
#   90,
#   93,
#   83,
#   75,
#   84,
#   79,
#   75,
#   94,
#   81,
#   86,
#   81,
#   79,
#   None,
#   79,
#   95,
#   75,
#   87,
#   81,
#   95,
#   81,
#   76,
#   82,
#   77,
#   92,
#   80,
#   84,
#   89,
#   86,
#   89,
#   81,
#   87,
#   86,
#   95,
#   82,
#   79,
#   84,
#   None,
#   87,
#   92,
#   84,
#   82,
#   81,
#   82,
#   78,
#   None,
#   None,
#   81,
#   90,
#   90,
#   95,
#   79,
#   81,
#   None,
#   95,
#   86,
#   79,
#   None,
#   75,
#   89,
#   77,
#   75,
#   87,
#   92,
#   None,
#   None,
#   77,
#   94,
#   94,
#   77,
#   79,
#   87,
#   80,
#   93,
#   86,
#   89,
#   84,
#   89,
#   80,
#   92,
#   82,
#   90,
#   93,
#   82,
#   91,
#   88,
#   None,
#   None,
#   92,
#   83,
#   77,
#   None,
#   86,
#   86,
#   89,
#   77,
#   92,
#   75,
#   75,
#   83,
#   95,
#   83,
#   95,
#   92,
#   75,
#   81,
#   78,
#   84,
#   76,
#   92,
#   81,
#   92,
#   82,
#   94,
#   94,
#   81,
#   94,
#   None,
#   80,
#   79,
#   89,
#   79,
#   85,
#   86,
#   81,
#   83,
#   80,
#   78,
#   None,
#   76,
#   82,
#   80,
#   95,
#   76,
#   89,
#   78,
#   86,
#   82,
#   84,
#   78,
#   94,
#   80,
#   None,
#   78,
#   95,
#   79,
#   None,
#   87,
#   95,
#   76,
#   None,
#   93,
#   81,
#   94,
#   84,
#   94,
#   90,
#   88,
#   76,
#   90,
#   90,
#   93,
#   77,
#   87,
#   None,
#   92,
#   None,
#   76,
#   90,
#   None,
#   86,
#   94,
#   90,
#   89,
#   84,
#   94,
#   85,
#   75,
#   94,
#   83,
#   81,
#   82,
#   75,
#   88,
#   82,
#   79,
#   88,
#   85,
#   80,
#   88,
#   91,
#   None,
#   84,
#   86,
#   93,
#   78,
#   77,
#   None,
#   75,
#   81,
#   90,
#   77,
#   87,
#   84,
#   79,
#   89,
#   92,
#   None,
#   None,
#   89,
#   83,
#   81,
#   91,
#   80,
#   87,
#   None,
#   76,
#   None,
#   84,
#   87,
#   88,
#   82,
#   81,
#   75,
#   95,
#   83,
#   87,
#   77,
#   93,
#   89,
#   78,
#   91,
#   82,
#   77,
#   95,
#   84,
#   83,
#   82,
#   89,
#   85,
#   80,
#   88,
#   84,
#   75,
#   75,
#   86,
#   92,
#   78,
#   89,
#   83,
#   93,
#   None,
#   85,
#   94,
#   85,
#   79,
#   76,
#   90,
#   88,
#   95,
#   None,
#   75,
#   84,
#   85,
#   78,
#   83,
#   87,
#   75,
#   80,
#   88,
#   90,
#   86,
#   91,
#   93,
#   None,
#   93,
#   94,
#   None,
#   85,
#   94,
#   77,
#   91,
#   85,
#   90,
#   95,
#   82,
#   None,
#   81,
#   85,
#   75,
#   77,
#   82,
#   87,
#   87,
#   81,
#   93,
#   80,
#   94,
#   82,
#   89,
#   79,
#   None,
#   76,
#   84,
#   83,
#   90,
#   77,
#   94,
#   87,
#   78,
#   91,
#   89,
#   76,
#   82,
#   86,
#   75,
#   92,
#   79,
#   87,
#   91,
#   95,
#   95,
#   77,
#   95,
#   93,
#   84,
#   80,
#   90,
#   81],
#  'Writing_score': [76,
#   78,
#   61,
#   70,
#   63,
#   61,
#   68,
#   66,
#   60,
#   62,
#   80,
#   64,
#   76,
#   68,
#   79,
#   60,
#   65,
#   79,
#   79,
#   71,
#   79,
#   69,
#   64,
#   80,
#   61,
#   78,
#   80,
#   72,
#   72,
#   76,
#   74,
#   80,
#   77,
#   70,
#   77,
#   62,
#   63,
#   66,
#   76,
#   76,
#   66,
#   72,
#   63,
#   66,
#   69,
#   71,
#   69,
#   60,
#   72,
#   78,
#   78,
#   68,
#   73,
#   76,
#   66,
#   63,
#   80,
#   63,
#   77,
#   70,
#   63,
#   67,
#   60,
#   64,
#   68,
#   76,
#   61,
#   76,
#   61,
#   73,
#   70,
#   79,
#   63,
#   61,
#   75,
#   62,
#   64,
#   72,
#   72,
#   80,
#   67,
#   77,
#   61,
#   70,
#   71,
#   65,
#   71,
#   73,
#   66,
#   78,
#   72,
#   67,
#   76,
#   78,
#   63,
#   75,
#   79,
#   71,
#   61,
#   64,
#   68,
#   65,
#   61,
#   62,
#   65,
#   68,
#   74,
#   64,
#   71,
#   67,
#   71,
#   69,
#   68,
#   80,
#   70,
#   63,
#   76,
#   78,
#   66,
#   67,
#   60,
#   74,
#   75,
#   71,
#   66,
#   77,
#   60,
#   67,
#   71,
#   72,
#   63,
#   68,
#   80,
#   72,
#   72,
#   69,
#   71,
#   69,
#   66,
#   69,
#   73,
#   76,
#   70,
#   64,
#   63,
#   64,
#   74,
#   72,
#   74,
#   60,
#   79,
#   75,
#   69,
#   60,
#   63,
#   60,
#   75,
#   63,
#   65,
#   63,
#   80,
#   80,
#   77,
#   79,
#   78,
#   72,
#   60,
#   67,
#   66,
#   63,
#   77,
#   73,
#   66,
#   78,
#   65,
#   76,
#   73,
#   78,
#   63,
#   79,
#   70,
#   64,
#   64,
#   78,
#   60,
#   77,
#   60,
#   74,
#   69,
#   71,
#   72,
#   74,
#   72,
#   62,
#   66,
#   60,
#   62,
#   64,
#   80,
#   60,
#   74,
#   66,
#   72,
#   61,
#   74,
#   77,
#   71,
#   76,
#   64,
#   65,
#   66,
#   69,
#   65,
#   77,
#   73,
#   74,
#   70,
#   62,
#   76,
#   78,
#   62,
#   71,
#   74,
#   62,
#   78,
#   75,
#   66,
#   78,
#   65,
#   65,
#   80,
#   76,
#   72,
#   74,
#   65,
#   61,
#   65,
#   77,
#   71,
#   78,
#   78,
#   76,
#   62,
#   76,
#   77,
#   80,
#   65,
#   70,
#   70,
#   80,
#   77,
#   66,
#   71,
#   69,
#   78,
#   73,
#   74,
#   68,
#   66,
#   64,
#   68,
#   72,
#   67,
#   79,
#   72,
#   75,
#   73,
#   73,
#   68,
#   72,
#   77,
#   60,
#   78,
#   71,
#   75,
#   63,
#   77,
#   76,
#   75,
#   62,
#   69,
#   61,
#   69,
#   77,
#   75,
#   75,
#   61,
#   70,
#   63,
#   72,
#   64,
#   65,
#   69,
#   77,
#   71,
#   71,
#   64,
#   69,
#   75,
#   68,
#   63,
#   79,
#   60,
#   75,
#   76,
#   60,
#   79,
#   61,
#   75,
#   80,
#   70,
#   60,
#   70,
#   65,
#   71,
#   65,
#   65,
#   60,
#   63,
#   77,
#   67,
#   73,
#   76,
#   75,
#   79,
#   70,
#   73,
#   78,
#   60,
#   79,
#   64,
#   72,
#   79,
#   70,
#   74,
#   75,
#   78,
#   78,
#   79,
#   63,
#   76,
#   80,
#   64,
#   66,
#   69,
#   68,
#   74,
#   77,
#   69,
#   79,
#   74,
#   79,
#   78,
#   64,
#   76,
#   72,
#   68,
#   78,
#   69,
#   64,
#   71,
#   67,
#   69,
#   62,
#   74,
#   63,
#   61,
#   78,
#   78,
#   65,
#   71,
#   80,
#   67,
#   66,
#   76,
#   73,
#   77,
#   79,
#   60,
#   67,
#   76,
#   73,
#   63,
#   68,
#   69,
#   61,
#   78,
#   76,
#   75,
#   74,
#   62,
#   71,
#   62,
#   73,
#   67,
#   67,
#   63,
#   71,
#   64,
#   77],
#  'Placement_score': [97,
#   99,
#   93,
#   100,
#   98,
#   77,
#   94,
#   81,
#   90,
#   89,
#   95,
#   99,
#   84,
#   96,
#   75,
#   75,
#   90,
#   83,
#   89,
#   90,
#   79,
#   82,
#   86,
#   82,
#   99,
#   93,
#   85,
#   89,
#   100,
#   79,
#   96,
#   88,
#   82,
#   83,
#   81,
#   77,
#   86,
#   87,
#   87,
#   76,
#   76,
#   75,
#   87,
#   76,
#   84,
#   85,
#   95,
#   89,
#   99,
#   94,
#   94,
#   97,
#   88,
#   82,
#   93,
#   94,
#   91,
#   80,
#   78,
#   85,
#   96,
#   95,
#   90,
#   81,
#   81,
#   95,
#   76,
#   75,
#   85,
#   76,
#   96,
#   79,
#   76,
#   86,
#   97,
#   86,
#   76,
#   75,
#   82,
#   75,
#   87,
#   100,
#   80,
#   97,
#   79,
#   85,
#   79,
#   96,
#   86,
#   87,
#   85,
#   88,
#   96,
#   82,
#   80,
#   84,
#   95,
#   83,
#   81,
#   85,
#   75,
#   85,
#   93,
#   95,
#   92,
#   81,
#   83,
#   88,
#   83,
#   94,
#   77,
#   87,
#   86,
#   82,
#   90,
#   84,
#   89,
#   86,
#   82,
#   77,
#   98,
#   98,
#   99,
#   92,
#   97,
#   83,
#   87,
#   82,
#   75,
#   89,
#   91,
#   76,
#   94,
#   87,
#   85,
#   82,
#   85,
#   86,
#   99,
#   86,
#   86,
#   89,
#   94,
#   81,
#   75,
#   89,
#   90,
#   98,
#   95,
#   94,
#   83,
#   87,
#   80,
#   100,
#   81,
#   77,
#   75,
#   82,
#   85,
#   75,
#   79,
#   90,
#   77,
#   75,
#   82,
#   91,
#   77,
#   100,
#   77,
#   85,
#   90,
#   96,
#   82,
#   96,
#   82,
#   77,
#   98,
#   87,
#   92,
#   100,
#   94,
#   86,
#   89,
#   75,
#   90,
#   96,
#   87,
#   86,
#   82,
#   88,
#   99,
#   87,
#   85,
#   100,
#   79,
#   80,
#   89,
#   79,
#   78,
#   96,
#   92,
#   88,
#   97,
#   82,
#   99,
#   95,
#   99,
#   83,
#   85,
#   79,
#   87,
#   75,
#   81,
#   91,
#   75,
#   86,
#   83,
#   95,
#   75,
#   100,
#   93,
#   100,
#   75,
#   90,
#   100,
#   96,
#   86,
#   89,
#   93,
#   82,
#   95,
#   99,
#   82,
#   88,
#   93,
#   78,
#   86,
#   93,
#   81,
#   78,
#   86,
#   94,
#   84,
#   91,
#   98,
#   84,
#   98,
#   95,
#   91,
#   76,
#   84,
#   86,
#   96,
#   79,
#   93,
#   76,
#   91,
#   87,
#   78,
#   90,
#   84,
#   89,
#   85,
#   91,
#   82,
#   93,
#   94,
#   99,
#   93,
#   91,
#   77,
#   93,
#   100,
#   89,
#   91,
#   87,
#   96,
#   91,
#   88,
#   76,
#   91,
#   92,
#   81,
#   87,
#   79,
#   76,
#   100,
#   97,
#   88,
#   77,
#   90,
#   94,
#   100,
#   85,
#   92,
#   81,
#   96,
#   90,
#   90,
#   86,
#   92,
#   91,
#   95,
#   90,
#   97,
#   100,
#   75,
#   93,
#   76,
#   96,
#   97,
#   84,
#   83,
#   81,
#   89,
#   96,
#   100,
#   76,
#   76,
#   100,
#   81,
#   77,
#   78,
#   90,
#   82,
#   87,
#   93,
#   78,
#   81,
#   99,
#   99,
#   97,
#   87,
#   97,
#   89,
#   84,
#   77,
#   86,
#   78,
#   80,
#   95,
#   78,
#   95,
#   84,
#   84,
#   77,
#   81,
#   81,
#   94,
#   85,
#   77,
#   87,
#   76,
#   82,
#   81,
#   93,
#   76,
#   83,
#   83,
#   100,
#   95,
#   83,
#   90,
#   76,
#   90,
#   79,
#   98,
#   96,
#   94,
#   78,
#   79,
#   99,
#   90,
#   88,
#   83,
#   88,
#   82,
#   80,
#   89,
#   77,
#   88,
#   98,
#   84,
#   88,
#   89,
#   78,
#   89,
#   80,
#   88,
#   81,
#   86,
#   90,
#   82,
#   79,
#   83,
#   92,
#   87,
#   91,
#   95,
#   76],
#  'Club_Join_Date': ['2021',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2021',
#   '2018',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2019',
#   '2020',
#   '2021',
#   '2019',
#   '2018',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2018',
#   '2021',
#   '2019',
#   '2020',
#   '2018',
#   '2020',
#   '2019',
#   '2018',
#   '2018',
#   '2020',
#   '2018',
#   '2019',
#   '2018',
#   '2019',
#   '2020',
#   '2019',
#   '2021',
#   '2018',
#   '2018',
#   '2021',
#   '2020',
#   '2020',
#   '2018',
#   '2020',
#   '2018',
#   '2021',
#   '2019',
#   '2020',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2021',
#   '2021',
#   '2018',
#   '2018',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2019',
#   '2018',
#   '2021',
#   '2021',
#   '2018',
#   '2018',
#   '2021',
#   '2021',
#   '2019',
#   '2018',
#   '2020',
#   '2019',
#   '2021',
#   '2019',
#   '2020',
#   '2020',
#   '2021',
#   '2021',
#   '2021',
#   '2018',
#   '2020',
#   '2020',
#   '2021',
#   '2021',
#   '2020',
#   '2020',
#   '2019',
#   '2021',
#   '2019',
#   '2021',
#   '2021',
#   '2020',
#   '2021',
#   '2019',
#   '2021',
#   '2019',
#   '2018',
#   '2021',
#   '2018',
#   '2018',
#   '2018',
#   '2018',
#   '2020',
#   '2018',
#   '2021',
#   '2021',
#   '2021',
#   '2021',
#   '2018',
#   '2019',
#   '2020',
#   '2018',
#   '2021',
#   '2020',
#   '2019',
#   '2019',
#   '2020',
#   '2019',
#   '2019',
#   '2018',
#   '2018',
#   '2021',
#   '2020',
#   '2021',
#   '2019',
#   '2019',
#   '2019',
#   '2018',
#   '2018',
#   '2019',
#   '2021',
#   '2021',
#   '2018',
#   '2020',
#   '2020',
#   '2021',
#   '2018',
#   '2021',
#   '2018',
#   '2021',
#   '2019',
#   '2020',
#   '2021',
#   '2018',
#   '2021',
#   '2021',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2018',
#   '2018',
#   '2021',
#   '2020',
#   '2020',
#   '2018',
#   '2019',
#   '2021',
#   '2018',
#   '2021',
#   '2018',
#   '2018',
#   '2018',
#   '2020',
#   '2018',
#   '2020',
#   '2021',
#   '2018',
#   '2021',
#   '2021',
#   '2020',
#   '2020',
#   '2020',
#   '2019',
#   '2021',
#   '2021',
#   '2018',
#   '2019',
#   '2018',
#   '2019',
#   '2018',
#   '2018',
#   '2019',
#   '2021',
#   '2019',
#   '2021',
#   '2021',
#   '2020',
#   '2019',
#   '2021',
#   '2019',
#   '2018',
#   '2018',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2021',
#   '2018',
#   '2018',
#   '2018',
#   '2020',
#   '2021',
#   '2018',
#   '2021',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2019',
#   '2019',
#   '2021',
#   '2021',
#   '2018',
#   '2019',
#   '2018',
#   '2019',
#   '2019',
#   '2021',
#   '2019',
#   '2019',
#   '2020',
#   '2018',
#   '2018',
#   '2019',
#   '2021',
#   '2018',
#   '2019',
#   '2019',
#   '2020',
#   '2021',
#   '2020',
#   '2018',
#   '2019',
#   '2021',
#   '2018',
#   '2018',
#   '2018',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2018',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2021',
#   '2020',
#   '2021',
#   '2019',
#   '2020',
#   '2019',
#   '2018',
#   '2020',
#   '2019',
#   '2020',
#   '2018',
#   '2018',
#   '2019',
#   '2018',
#   '2021',
#   '2020',
#   '2019',
#   '2018',
#   '2018',
#   '2020',
#   '2018',
#   '2021',
#   '2019',
#   '2021',
#   '2021',
#   '2021',
#   '2018',
#   '2021',
#   '2020',
#   '2021',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2021',
#   '2019',
#   '2018',
#   '2021',
#   '2020',
#   '2018',
#   '2018',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2018',
#   '2018',
#   '2018',
#   '2021',
#   '2018',
#   '2021',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2020',
#   '2018',
#   '2019',
#   '2019',
#   '2018',
#   '2021',
#   '2021',
#   '2019',
#   '2019',
#   '2020',
#   '2020',
#   '2020',
#   '2020',
#   '2021',
#   '2019',
#   '2020',
#   '2021',
#   '2019',
#   '2020',
#   '2019',
#   '2019',
#   '2018',
#   '2020',
#   '2021',
#   '2019',
#   '2019',
#   '2018',
#   '2020',
#   '2019',
#   '2020',
#   '2021',
#   '2019',
#   '2019',
#   '2020',
#   '2018',
#   '2020',
#   '2018',
#   '2020',
#   '2020',
#   '2019',
#   '2021',
#   '2019',
#   '2018',
#   '2018',
#   '2019',
#   '2018',
#   '2018',
#   '2018',
#   '2018',
#   '2018',
#   '2019',
#   '2019',
#   '2021',
#   '2019',
#   '2021',
#   '2020',
#   '2020',
#   '2018',
#   '2019',
#   '2018',
#   '2018',
#   '2019',
#   '2018',
#   '2019',
#   '2018',
#   '2020',
#   '2020',
#   '2018',
#   '2020',
#   '2020',
#   '2019',
#   '2021',
#   '2019',
#   '2020',
#   '2020',
#   '2020',
#   '2020',
#   '2021',
#   '2019',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2018',
#   '2019',
#   '2021',
#   '2020']}

# %%
dataFrame = pd.DataFrame(df)

# %%
dataFrame.to_csv("Student_performance.csv")

# %%
dataFrame.shape
# Out:
# (400, 5)

# %%
dataFrame.head()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 0        78.0           80.0             76               97           2021
# 1        68.0           84.0             78               99           2020
# 2        79.0           87.0             61               93           2019
# 3        66.0            NaN             70              100           2021
# 4         NaN           85.0             63               98           2020

# %%
dataFrame.tail()
# Out:
#      Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 395        67.0           93.0             67               92           2020
# 396        69.0           84.0             63               87           2018
# 397         NaN           80.0             71               91           2019
# 398        71.0           90.0             64               95           2021
# 399        66.0           81.0             77               76           2020

# %%
dataFrame.sample(5)
# Out:
#      Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 45         64.0           87.0             71               85           2020
# 114        67.0           82.0             70               90           2019
# 126         NaN           86.0             60               87           2021
# 123        61.0           81.0             71               92           2019
# 193        64.0           85.0             62              100           2019

# %%
dataFrame.columns
# Out:
# Index(['Math_score', 'Reading_score', 'Writing_score', 'Placement_score',
#        'Club_Join_Date'],
#       dtype='object')

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_score       320 non-null    float64
#  1   Reading_score    360 non-null    float64
#  2   Writing_score    400 non-null    int64
#  3   Placement_score  400 non-null    int64
#  4   Club_Join_Date   400 non-null    object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 15.8+ KB

# %%
dataFrame.dtypes
# Out:
# Math_score         float64
# Reading_score      float64
# Writing_score        int64
# Placement_score      int64
# Club_Join_Date      object
# dtype: object

# %%
dataFrame['Club_Join_Date']=dataFrame['Club_Join_Date'].astype("datetime64[ns]")

# %%
dataFrame.dtypes
# Out:
# Math_score                float64
# Reading_score             float64
# Writing_score               int64
# Placement_score             int64
# Club_Join_Date     datetime64[ns]
# dtype: object

# %%
dataFrame.iloc[:,0:4].head(5)
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score
# 0        78.0           80.0             76               97
# 1        68.0           84.0             78               99
# 2        79.0           87.0             61               93
# 3        66.0            NaN             70              100
# 4         NaN           85.0             63               98

# %%
dataFrame.loc[:,["Placement_score","Club_Join_Date"]].head(5)
# Out:
#    Placement_score Club_Join_Date
# 0               97     2021-01-01
# 1               99     2020-01-01
# 2               93     2019-01-01
# 3              100     2021-01-01
# 4               98     2020-01-01

# %%
dataFrame['Club_Join_Date'].value_counts()
# Out:
# 2018-01-01    111
# 2021-01-01    108
# 2019-01-01     95
# 2020-01-01     86
# Name: Club_Join_Date, dtype: int64

# %%
dataFrame.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
dataFrame.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score
# count  320.000000     360.000000     400.000000       400.000000
# mean    70.259375      84.722222      70.257500        87.097500
# std      6.059132       6.187917       6.113479         7.385754
# min     60.000000      75.000000      60.000000        75.000000
# 25%     65.000000      80.000000      65.000000        81.000000
# 50%     71.000000      84.000000      71.000000        87.000000
# 75%     76.000000      90.000000      76.000000        93.000000
# max     80.000000      95.000000      80.000000       100.000000

# %%
dataFrame.duplicated().sum()
# Out:
# 0

# %%
dataFrame.nunique()
# Out:
# Math_score         21
# Reading_score      21
# Writing_score      21
# Placement_score    26
# Club_Join_Date      4
# dtype: int64

# %%
dataFrame.isnull().sum()
# Out:
# Math_score         80
# Reading_score      40
# Writing_score       0
# Placement_score     0
# Club_Join_Date      0
# dtype: int64

# %%
dataFrame['Math_score'].fillna(dataFrame['Math_score'].mean(), inplace=True)
dataFrame['Reading_score'].fillna(dataFrame['Reading_score'].mean(), inplace=True)

# %%
dataFrame.isnull().sum()
# Out:
# Math_score         0
# Reading_score      0
# Writing_score      0
# Placement_score    0
# Club_Join_Date     0
# dtype: int64

# %%
pd.get_dummies(dataFrame,columns=['Club_Join_Date']).head()  # label Encoding
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score  \
# 0   78.000000      80.000000             76               97
# 1   68.000000      84.000000             78               99
# 2   79.000000      87.000000             61               93
# 3   66.000000      84.722222             70              100
# 4   70.259375      85.000000             63               98
#
#    Club_Join_Date_2018-01-01 00:00:00  Club_Join_Date_2019-01-01 00:00:00  \
# 0                                   0                                   0
# 1                                   0                                   0
# 2                                   0                                   1
# 3                                   0                                   0
# 4                                   0                                   0
#
#    Club_Join_Date_2020-01-01 00:00:00  Club_Join_Date_2021-01-01 00:00:00
# 0                                   0                                   1
# 1                                   1                                   0
# 2                                   0                                   0
# 3                                   0                                   1
# 4                                   1                                   0

# %%
# Generating outliers
for i in [random.randint(0, 400) for _ in range(8)]:
    
    dataFrame['Math_score'][i] = random.randint(-10, 20)

# %%
dataFrame['Math_score'].describe()
# Out:
# count    400.000000
# mean      68.810578
# std       11.333557
# min      -10.000000
# 25%       66.000000
# 50%       70.259375
# 75%       74.000000
# max       80.000000
# Name: Math_score, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataFrame['Math_score'])

plt.subplot(2,2,2)
sns.boxplot(dataFrame['Math_score'])
# Out:
# <AxesSubplot: >

# %%
percentile25 = dataFrame['Math_score'].quantile(0.25)
percentile75 = dataFrame['Math_score'].quantile(0.75)

# %%
percentile25
# Out:
# 66.0

# %%
percentile75
# Out:
# 74.0

# %%
iqr = percentile75 - percentile25
iqr
# Out:
# 8.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 86.0
# Lower limit 54.0

# %%
dataFrame[dataFrame['Math_score'] > upper_limit]
# Out:
# Empty DataFrame
# Columns: [Math_score, Reading_score, Writing_score, Placement_score, Club_Join_Date]
# Index: []

# %%
dataFrame[dataFrame['Math_score'] < lower_limit]
# Out:
#      Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 27        -10.0      84.722222             72               89     2020-01-01
# 161         4.0      77.000000             80               90     2019-01-01
# 171        14.0      95.000000             73               96     2021-01-01
# 177        -7.0      78.000000             78               87     2020-01-01
# 254        -6.0      88.000000             78               93     2018-01-01
# 300       -10.0      89.000000             63               92     2019-01-01
# 330        -1.0      95.000000             64               99     2019-01-01
# 385        13.0      86.000000             61               78     2019-01-01

# %%
new_dataFrame = dataFrame[dataFrame['Math_score'] > lower_limit]
new_dataFrame.shape
# Out:
# (392, 5)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataFrame['Math_score'])

plt.subplot(2,2,2)
sns.boxplot(dataFrame['Math_score'])

plt.subplot(2,2,3)
sns.distplot(new_dataFrame['Math_score'])

plt.subplot(2,2,4)
sns.boxplot(new_dataFrame['Math_score'])

plt.show()

# %%
new_df_cap = dataFrame.copy()

new_df_cap['Math_score'] = np.where(
    new_df_cap['Math_score'] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap['Math_score'] < lower_limit,
        lower_limit,
        new_df_cap['Math_score']
    )
)

# %%
new_df_cap.shape
# Out:
# (400, 5)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataFrame['Math_score'])

plt.subplot(2,2,2)
sns.boxplot(dataFrame['Math_score'])

plt.subplot(2,2,3)
sns.distplot(new_df_cap['Math_score'])

plt.subplot(2,2,4)
sns.boxplot(new_df_cap['Math_score'])

plt.show()
